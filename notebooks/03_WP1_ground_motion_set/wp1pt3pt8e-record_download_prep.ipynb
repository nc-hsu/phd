# %%
import pandas as pd

from phd_project.config import config

cfg = config.load_config()

# %%
# load the records needed for each of the IMs
esm_avgsa03 = pd.read_csv(cfg["proc_data"]["gm_selection"] / "esm_records_to_download_AvgSA03.csv", header=1)
nga_avgsa03 = pd.read_csv(cfg["proc_data"]["gm_selection"] / "ngasub_to_download_AvgSA03.csv", header=1)

# esm_avgsa06 = pd.read_csv(cfg["proc_data"]["gm_selection"] / "esm_records_to_download_AvgSA06.csv", header=1)
# nga_avgsa06 = pd.read_csv(cfg["proc_data"]["gm_selection"] / "ngasub_to_download_AvgSA06.csv", header=1)
